# %%
import pandas as pd
import numpy as np

spectra = pd.read_csv('spectra.dat', delimiter=' ', header=None)
spectra.head
# Out:
# <bound method NDFrame.head of           0         1         2         3         4         5         6    \
# 0    0.010532  0.011854  0.011477  0.011186  0.010723  0.007781  0.003281
# 1    0.012206  0.013479  0.013350  0.013068  0.013404  0.011025  0.005107
# 2    0.003660  0.004010  0.004001  0.003920  0.004109  0.003515  0.001691
# 3    0.065447  0.071665  0.071253  0.069657  0.072569  0.061464  0.029246
# 4    0.143073  0.156413  0.155725  0.152241  0.159254  0.135972  0.065265
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.084785  0.092999  0.092949  0.091197  0.095809  0.082226  0.039687
# 996  0.014452  0.015888  0.016062  0.015868  0.017012  0.015016  0.007340
# 997  0.153889  0.168172  0.167482  0.163732  0.171433  0.146658  0.070557
# 998  0.025145  0.027639  0.027524  0.026976  0.028090  0.023713  0.011243
# 999  0.046592  0.051136  0.051223  0.050333  0.053077  0.045830  0.022268
#
#           7         8         9    ...       840       841       842  \
# 0    0.007836  0.008751  0.012667  ...  0.024035  0.023810  0.024046
# 1    0.011005  0.012001  0.014975  ...  0.045495  0.044942  0.045321
# 2    0.003498  0.003792  0.004505  ...  0.016169  0.015951  0.016057
# 3    0.060936  0.065971  0.078945  ...  0.052733  0.051933  0.052260
# 4    0.134719  0.145695  0.172647  ...  0.071784  0.070843  0.071313
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.082043  0.089028  0.105681  ...  0.237033  0.234978  0.237017
# 996  0.015144  0.016453  0.019114  ...  0.116852  0.117667  0.119247
# 997  0.145284  0.157084  0.185707  ...  0.077033  0.076005  0.076492
# 998  0.023641  0.025681  0.031034  ...  0.054181  0.053688  0.054170
# 999  0.045849  0.049797  0.058873  ...  0.120998  0.121018  0.122442
#
#           843       844       845       846       847       848       849
# 0    0.023865  0.023751  0.023780  0.023700  0.023532  0.023523  0.023560
# 1    0.044943  0.044721  0.044843  0.044598  0.043910  0.043594  0.043794
# 2    0.015907  0.015811  0.015818  0.015722  0.015475  0.015348  0.015374
# 3    0.051681  0.051270  0.051238  0.050767  0.049790  0.049233  0.049177
# 4    0.070579  0.070022  0.069911  0.069362  0.068354  0.067859  0.067661
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.236048  0.235719  0.236943  0.236522  0.234346  0.233746  0.235702
# 996  0.120329  0.121477  0.123043  0.124556  0.126414  0.128591  0.131057
# 997  0.075710  0.075119  0.075009  0.074406  0.073292  0.072723  0.072523
# 998  0.053871  0.053724  0.053934  0.053792  0.053276  0.053137  0.053471
# 999  0.122760  0.123251  0.124308  0.125061  0.125763  0.127002  0.128654
#
# [1000 rows x 850 columns]>

# %%
wavelengths = pd.read_csv('wavelengths.csv', header=None)
wavelengths.head
# Out:
# <bound method NDFrame.head of              0
# 0     1995.952
# 1     2005.169
# 2     2014.430
# 3     2023.732
# 4     2033.078
# ..         ...
# 845  97947.983
# 846  98400.317
# 847  98854.740
# 848  99311.262
# 849  99769.891
#
# [850 rows x 1 columns]>

# %%
galaxy_properties = pd.read_csv('galaxy_properties.csv', index_col = 0)
galaxy_properties.head
# Out:
# <bound method NDFrame.head of       dust_av       age      mass    tauGyr
# idx
# 0    0.164869  0.203291  7.885367  0.033035
# 1    0.200852  0.470248  8.297678  0.087146
# 2    0.197863  4.033993  8.184615  1.273974
# 3    0.001000  0.721636  8.360110  0.242588
# 4    0.001000  0.699464  8.373327  0.510683
# ..        ...       ...       ...       ...
# 995  0.322905  2.018232  8.987870  2.069916
# 996  0.870794  0.075134  7.607796  0.062845
# 997  0.001000  0.849640  8.415094  0.918643
# 998  0.232163  0.586724  8.286425  0.168273
# 999  0.456984  0.612213  8.276157  3.523973
#
# [1000 rows x 4 columns]>

# %%
import matplotlib
import matplotlib.pyplot as plt
import random
# %matplotlib inline

random.seed(1010) # for reproducibility
rows = [random.randint(0, len(spectra)) for i in range(3)]  # select three random galaxy spectrums to visualize

plt.rcParams["figure.figsize"] = (20,10) #set size of plot

fig = plt.figure()
ax = fig.add_subplot(111) # Generating subplots for our figure; see https://stackoverflow.com/a/6981055/3135556
ax1 = fig.add_subplot(311) # 3 rows, 1 column, plot at position 1
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

# Turn off axis lines and ticks of the big subplot
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

ax1.plot(wavelengths, spectra.loc[rows[0]], 'r,-')
ax2.plot(wavelengths, spectra.loc[rows[1]], 'r,-')
ax3.plot(wavelengths, spectra.loc[rows[2]], 'r,-')

ax1.set_xlim(1000, 100000) # restrict the x-axis to mitigate the gap that exists around x=0
ax2.set_xlim(1000, 100000)
ax3.set_xlim(1000, 100000)

# Set common labels
ax.set_xlabel("Wavelength (Å)", fontsize=16, labelpad=18)
ax.set_ylabel("Flux (μJy)", fontsize=16, labelpad=20)
ax.set_title("Visualizing Our Data", fontsize=24, pad=36)

ax1.set_title("Spectrum for Galaxy #" + str(rows[0]))
ax2.set_title("Spectrum for Galaxy #" + str(rows[1]))
ax3.set_title("Spectrum for Galaxy #" + str(rows[2]))

plt.subplots_adjust(hspace=0.4) # increase vertical distance between subplots

# %% [markdown]
# ## Predicting Age

# %%
ages = galaxy_properties['age']
ages.head

X = np.empty(len(spectra))
for i in range(len(spectra)):
    X[i] = np.log(np.sum(spectra.loc[i]))

plt.scatter(X, ages)

# %%
X = np.empty(len(spectra))
for i in range(len(spectra)):
    X[i] = np.sum(spectra.loc[i])

plt.scatter(ages, X)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import RidgeCV, Ridge, Lasso, LassoCV
from sklearn.model_selection import cross_val_predict, cross_val_score, cross_validate
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(spectra, ages, random_state=101)

model = Ridge()
model.fit(X_train, y_train)
mean_squared_error(y_test, model.predict(X_test))
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
model = Ridge()
cv = KFold(n_splits=5, shuffle=True, random_state=101)
cross_val = cross_validate(model, X_train, y_train, cv = cv, scoring = 'neg_mean_squared_error', return_train_score=True)
cross_val
# Out:
# {'fit_time': array([0.02129793, 0.01966405, 0.01804328, 0.01613593, 0.01678181]),
#  'score_time': array([0.00783992, 0.00690293, 0.00553393, 0.00657105, 0.00670719]),
#  'test_score': array([-0.47826229, -0.84259982, -0.56332484, -0.58760169, -0.7931765 ]),
#  'train_score': array([-0.65113735, -0.55174288, -0.63313297, -0.60785145, -0.55811991])}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

alphas = [0.01, 0.1, 1.0, 10.0, 100.0]
model = Ridge(alpha=1, normalize=True)
model.fit(X_train, y_train)
mean_squared_error(y_test, model.predict(X_test))
# Out:
# 0.6664077532432541

# %%
model = Ridge()
model.get_params()
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.001}

# %%
model = SVR()
cv = KFold(n_splits=5, shuffle=True, random_state=101)
l_benchmark_lim = cross_validate(model, spectra, ages, cv = cv, scoring = 'neg_mean_squared_error', return_train_score=True)
l_benchmark_lim

model.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# ### Data preprocessing

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(spectra)
scaled_spectra = scaler.transform(spectra)

# %%
Y = np.empty(len(scaled_spectra))
for i in range(len(scaled_spectra)):
    Y[i] = np.sum(scaled_spectra[i])

plt.scatter(ages, Y)

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_spectra, ages, random_state=101)
svr = SVR(verbose=True)
cv = KFold(n_splits=3, shuffle=True, random_state=101)
svr.fit(X_train, y_train)

X_train2, X_test2, y_train2, y_test2 = train_test_split(spectra, ages, random_state=101)
svr2 = SVR(verbose=True)
svr2.fit(X_train2, y_train2)
# Out:
# [LibSVM][LibSVM]
# SVR(verbose=True)

# %%
print(mean_squared_error(y_test, svr.predict(X_test)))
print(mean_squared_error(y_test2, svr2.predict(X_test2)))
# Out:
# 0.6583284599831433
# 0.6648831303746613

# %%
# -0.5871 {'C': 10, 'degree': 1, 'kernel': 'rbf'}

# %%
svr = SVR(verbose=True)
cv = KFold(n_splits=5, shuffle=True, random_state=101)
# l_benchmark_lim = cross_validate(model, spectra, ages, cv = cv, scoring = 'neg_mean_squared_error', return_train_score=True)
# l_benchmark_lim

params = {
    'C': [0.01, 0.1, 1.0, 1, 10],
    'degree': [1, 3, 5, 7],
    'kernel': ['poly', 'rbf'],
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-4, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [Parallel(n_jobs=-4)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-4)]: Done   8 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-4)]: Done  62 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-4)]: Done 152 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-4)]: Done 200 out of 200 | elapsed:  5.7min finished
# [LibSVM]Best params, best score: -0.5935 {'C': 10, 'degree': 1, 'kernel': 'rbf'}

# %%
params = {
    'C': [1, 10, 50, 100, 100, 500, 1000],
    'kernel': ['rbf'],
    'gamma': ['auto', 'scale', 0.1, 1.0, 10.0, 100.0]
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-4, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# [Parallel(n_jobs=-4)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-4)]: Done   8 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-4)]: Done  62 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-4)]: Done 152 tasks      | elapsed:   56.4s
# [Parallel(n_jobs=-4)]: Done 210 out of 210 | elapsed:  1.4min finished
# [LibSVM]Best params, best score: -0.1876 {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
params = {
    'C': [500, 800, 1000, 1200, 1500, 2000],
    'kernel': ['rbf'],
    'gamma': [0.01, 0.06, 0.1, 1.0, 5.0, 10.0]
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-4, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-4)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-4)]: Done   8 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-4)]: Done  62 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-4)]: Done 152 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-4)]: Done 180 out of 180 | elapsed:  1.6min finished
# [LibSVM]Best params, best score: -0.1829 {'C': 2000, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
params = {
    'C': [1800, 1900, 2000, 2100, 2200, 2300, 2400],
    'kernel': ['rbf'],
    'gamma': np.arange(0.05, 0.15, 0.01)
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 70 candidates, totalling 350 fits
# [Parallel(n_jobs=-4)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-4)]: Done   8 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-4)]: Done  62 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=-4)]: Done 152 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-4)]: Done 278 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-4)]: Done 350 out of 350 | elapsed:  5.1min finished
# [LibSVM]Best params, best score: -0.1798 {'C': 2300, 'gamma': 0.08000000000000002, 'kernel': 'rbf'}

# %%
params = {
    'C': np.arange(2250, 2350, 10),
    'kernel': ['rbf'],
    'gamma': np.arange(0.05, 0.10, 0.01)
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-3)]: Done   6 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-3)]: Done  60 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=-3)]: Done 150 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-3)]: Done 250 out of 250 | elapsed:  3.6min finished
# [LibSVM]Best params, best score: -0.1798 {'C': 2300, 'gamma': 0.08000000000000002, 'kernel': 'rbf'}

# %%
params = {
    'C': [1, 10, 50, 100, 100, 500, 1000],
    'kernel': ['rbf'],
    'gamma': ['auto', 'scale', 0.1, 1.0, 10.0, 100.0]
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(scaled_spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-3)]: Done   6 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-3)]: Done  60 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-3)]: Done 150 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-3)]: Done 210 out of 210 | elapsed:  1.4min finished
# [LibSVM]Best params, best score: -0.2126 {'C': 1000, 'gamma': 1.0, 'kernel': 'rbf'}

# %%
params = {
    'C': [800, 900, 1000, 1100, 1200],
    'kernel': ['rbf'],
    'gamma': [0.1, 0.5, 1.0, 1.5, 2.0]
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(scaled_spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-3)]: Done   6 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-3)]: Done  60 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-3)]: Done 125 out of 125 | elapsed:  1.3min finished
# [LibSVM]Best params, best score: -0.1954 {'C': 1000, 'gamma': 0.5, 'kernel': 'rbf'}

# %%
params = {
    'C': [600, 700, 800, 900, 1000, 1100, 1200],
    'kernel': ['rbf'],
    'gamma': np.arange(0.2, 0.8, 0.1)
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(scaled_spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-3)]: Done   6 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-3)]: Done  60 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-3)]: Done 150 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-3)]: Done 245 out of 245 | elapsed:  2.6min finished
# [LibSVM]Best params, best score: -0.1865 {'C': 1000, 'gamma': 0.30000000000000004, 'kernel': 'rbf'}

# %%
params = {
    'C': np.arange(950, 1050, 10),
    'kernel': ['rbf'],
    'gamma': np.arange(0.1, 0.5, 0.05)
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(scaled_spectra, ages)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-3)]: Done   6 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-3)]: Done  60 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-3)]: Done 150 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-3)]: Done 276 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-3)]: Done 400 out of 400 | elapsed:  3.9min finished
# [LibSVM]Best params, best score: -0.1865 {'C': 1010, 'gamma': 0.30000000000000004, 'kernel': 'rbf'}

# %%
params = {
    'C': [1000, 1100, 1200, 1250, 1300, 1350, 1400, 1600],
    'kernel': ['rbf'],
    'gamma': [0.01, 0.025, 0.05, 0.055, 0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.9, 0.1]
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(X_train, y_train)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)

# %%
params = {
    'C': [1400, 1500, 1550, 1600, 1650, 1700, 1800, 1900, 2000],
    'kernel': ['rbf'],
    'gamma': [0.06, 0.065, 0.07, 0.075, 0.0775, 0.08, 0.0825, 0.085, 0.9, 0.1]
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(X_train, y_train)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)

# %%
c_space = np.arange(1600, 2000, 10)
g_space = np.arange(0.5, 1.0, 0.01)
params = {
    'C': c_space,
    'kernel': ['rbf'],
    'gamma': g_space
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(X_train, y_train)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)

# %%
c_space = np.arange(1600, 2000, 10)
g_space = np.arange(0.2, 0.7, 0.01)
params = {
    'C': c_space,
    'kernel': ['rbf'],
    'gamma': g_space
}

model = GridSearchCV(svr, params, cv = cv, verbose=5, n_jobs=-3, return_train_score=True, scoring='neg_mean_squared_error')
model.fit(X_train, y_train)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 2000 candidates, totalling 10000 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-3)]: Done   6 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-3)]: Done  60 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-3)]: Done 150 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-3)]: Done 276 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-3)]: Done 438 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-3)]: Done 636 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-3)]: Done 870 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-3)]: Done 1140 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-3)]: Done 1446 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-3)]: Done 1788 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-3)]: Done 2166 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-3)]: Done 2580 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-3)]: Done 3030 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-3)]: Done 3516 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-3)]: Done 4038 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=-3)]: Done 4596 tasks      | elapsed: 27.4min
# [Parallel(n_jobs=-3)]: Done 5190 tasks      | elapsed: 31.0min
# [Parallel(n_jobs=-3)]: Done 5820 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=-3)]: Done 6486 tasks      | elapsed: 39.0min
# [Parallel(n_jobs=-3)]: Done 7188 tasks      | elapsed: 43.3min
# [Parallel(n_jobs=-3)]: Done 7926 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-3)]: Done 8700 tasks      | elapsed: 52.8min
# [Parallel(n_jobs=-3)]: Done 9510 tasks      | elapsed: 57.9min
# [Parallel(n_jobs=-3)]: Done 10000 out of 10000 | elapsed: 61.0min finished
# [LibSVM]Best params, best score: -0.2050 {'C': 1990, 'gamma': 0.34000000000000014, 'kernel': 'rbf'}

# %%
pd.DataFrame.from_dict(model.cv_results_).sort_values(by='rank_test_score', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a09ea6ce93bf> in <module>
# ----> 1 pd.DataFrame.from_dict(model.cv_results_).sort_values(by='rank_test_score', ascending=True)
#
# NameError: name 'pd' is not defined

# %%
best_model = model.best_estimator_
best_model.fit(X_train, y_train)
print(mean_squared_error(y_test, best_model.predict(X_test)))
# Out:
# [LibSVM]0.3003747024706257

# %%
X = np.empty(len(X_test))
for i in range(len(X_test)):
    X[i] = np.sum(X_test[i])

plt.scatter(X, y_test, color='r')
plt.scatter(X, best_model.predict(X_test), color='b')

# %%
X_train, X_test, y_train, y_test = train_test_split(spectra, ages, random_state=101)
alphas = [0.1, 0.5, 1.0, 5.0, 10.0, 50.0, 100.0]
model = RidgeCV(alphas=alphas, scoring='neg_mean_squared_error', cv=cv)
model.fit(X_train, y_train)

# %%
print(model.best_score_)

# %%
alphas = np.array([0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0, 10., 100., 1000.])
ridge_model = RidgeCV(alphas=alphas, normalize=True, cv = KFold(n_splits=10, shuffle=True, random_state=1), scoring = 'neg_mean_squared_error')
ridge_model.fit(X_train, y_train)

# %%
ridge_model.best_score_

# %%
lasso_model = LassoCV(alphas=alphas, normalize=True, cv = KFold(n_splits=10, shuffle=True, random_state=1), max_iter=2000)
lasso_model.fit(X_train, y_train)

# %%
lasso_model.mse_path_.min()

# %%
X_train, X_test, y_train, y_test = train_test_split(spectra, ages, random_state=101)
model = DecisionTreeRegressor(splitter="best", random_state=101)
model.fit(X_train, y_train)

# %%
print(mean_squared_error(y_test, model.predict(X_test)))

# %% [markdown]
# # Best Estimator: [LibSVM]Best params, best score: -0.1798 {'C': 2300, 'gamma': 0.08000000000000002, 'kernel': 'rbf'}
# ## Using reg data
#
# # Best Estimator: [LibSVM]Best params, best score: -0.1865 {'C': 1010, 'gamma': 0.30000000000000004, 'kernel': 'rbf'}
# ## Using scaled data

# %%
from sklearn.metrics import r2_score
X_train, X_test, y_train, y_test = train_test_split(spectra, ages, random_state=101)
model = SVR(C=2300, gamma=0.08, kernel='rbf')
model.fit(X_train, y_train)
print(r2_score(y_test, model.predict(X_test)))
# Out:
# 0.6926516982368061

# %%
model = SVR(C=2300, gamma=0.08, kernel='rbf')
model.fit(X_train, y_train)
print(mean_squared_error(y_test, model.predict(X_test)))
# Out:
# 0.21846968663353358

# %%
X_train, X_test, y_train, y_test = train_test_split(spectra, ages, random_state=101)
model = SVR(C=1990, gamma=0.34, kernel='rbf')
model.fit(X_train, y_train)
print(mean_squared_error(y_test, model.predict(X_test)))
# Out:
# 0.32108704619970974

# %%
model = SVR(C=1720, gamma=0.5, kernel='rbf')
model.fit(X_train, y_train)
print(mean_squared_error(y_test, model.predict(X_test)))
# Out:
# 0.3003747024706257

# %%
from sklearn.metrics import r2_score
model = SVR(C=1990, gamma=0.34, kernel='rbf')
model.fit(X_train, y_train)
print(r2_score(y_test, model.predict(X_test)))

model = SVR(C=1720, gamma=0.5, kernel='rbf')
model.fit(X_train, y_train)
print(r2_score(y_test, model.predict(X_test)))
# Out:
# 0.5482871793871404
# 0.5774257924769639

# %%
from sklearn.metrics import r2_score
model = SVR(C=1990, gamma=0.34, kernel='rbf')
model.fit(X_train, y_train)
print(r2_score(ages, model.predict(spectra)))

model = SVR(C=1720, gamma=0.5, kernel='rbf')
model.fit(X_train, y_train)
print(r2_score(ages, model.predict(spectra)))
# Out:
# 0.8527260099266947
# 0.8641147918636145

# %%
model = SVR(C=1990, gamma=0.34, kernel='rbf')
model.fit(X_train, y_train)
print(mean_squared_error(ages, model.predict(spectra)))

model = SVR(C=1720, gamma=0.5, kernel='rbf')
model.fit(X_train, y_train)
print(mean_squared_error(ages, model.predict(spectra)))
# Out:
# 0.09893047022387043
# 0.09128012034378773

# %%
model = SVR(C=1720, gamma=0.5, kernel='rbf')
model.fit(X_train, y_train)
print(mean_squared_error(ages, model.predict(spectra)))

# %%
X = np.empty(len(X_train))
for i in range(len(X_train)):
    X[i] = np.log(np.sum(X_train[i]))
    
X2 = np.empty(len(X_test))
for i in range(len(X_test)):
    X2[i] = np.log(np.sum(X_test[i]))

fig, ax = plt.subplots()
ax.scatter(X, y_train, color='gray', label='Training data')
ax.scatter(X2, y_test, color='red', label='Test data (actual)')
ax.scatter(X2, model.predict(X_test), color='blue', label='Test data (predicted)')
ax.legend()
ax.set_title("Model Performance", fontsize=16)
plt.show()
fig.savefig("model_perfomance", dpi=300)

# %%
X = np.empty(len(spectra))
for i in range(len(spectra)):
    X[i] = np.log(np.sum(spectra.loc[i]))

fig, ax = plt.subplots()
ax.scatter(X, ages, color='red', label='Actual values')
plt.scatter(X, model.predict(spectra), color='blue', label='Predicted values')
ax.legend()
ax.set_title("Model Performance 2", fontsize=16)
fig.savefig("model_perfomance2", dpi=300)

# %%
tau = galaxy_properties['tauGyr']
np.std(tau)
# Out:
# 1.4291088390334348

# %%
np.range(tau)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-fa46c5772879> in <module>
# ----> 1 np.range(tau)
#
# ~/.conda/envs/PHYS3600ID/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     212                 return Tester
#     213             else:
# --> 214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#     216
#
# AttributeError: module 'numpy' has no attribute 'range'

# %%
np.where(tau > 1.0)
# Out:
# (array([  2,   8,   9,  10,  20,  21,  39,  65,  79,  82,  85,  92, 112,
#         124, 142, 143, 155, 158, 160, 173, 181, 185, 186, 215, 217, 219,
#         221, 229, 230, 232, 234, 240, 248, 268, 270, 282, 286, 294, 315,
#         318, 322, 357, 359, 365, 372, 376, 378, 387, 391, 393, 398, 407,
#         413, 414, 431, 442, 466, 470, 472, 478, 484, 497, 501, 505, 532,
#         534, 547, 550, 562, 564, 569, 570, 583, 598, 599, 613, 614, 616,
#         624, 635, 642, 644, 667, 670, 680, 683, 685, 700, 703, 713, 722,
#         734, 749, 761, 765, 773, 777, 780, 782, 789, 801, 802, 803, 807,
#         816, 820, 842, 850, 862, 872, 879, 882, 883, 894, 920, 924, 926,
#         927, 934, 937, 968, 994, 995, 999]),)
